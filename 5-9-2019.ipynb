# %% [markdown]
# # markdown introduction

# %% [markdown]
# # heading1
# ## heading2
# ### heading3
# #### heading4
# ##### heading5
# ###### heading6

# %% [markdown]
# **bold**

# %% [markdown]
# *italic*<br/>
# <strike>striking text</strike><br/>
# `highligthing`

# %% [markdown]
# <img src="https://icon-library.net/images/python-icon/python-icon-10.jpg" width="100px" height="100px">

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%HTML
# <iframe width="400" height="400" src="https://www.youtube.com/embed/hEgO047GxaQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="400" height="400" src="https://www.youtube.com/embed/hEgO047GxaQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# * python
# * java
# * R programming
# * scripting languages
#    - html
#    - xml

# %% [markdown]
# ## python programming

# %%
print("hello world")
print("bhanu what are you doing?")
# Out:
# hello world
# bhanu what are you doing?

# %%
print(1)
# Out:
# 1

# %% [markdown]
# ### operators

# %% [markdown]
# * arithmetic operators
# * relational operators
# * assignment operators
# * logical operators
# * bit wise operators
# * identify operaors
# * membership operators

# %% [markdown]
# ### arithmetic operators

# %%
print(60+40)
print(60-40)
print(60/40)
print(60*60)
# Out:
# 100
# 20
# 1.5
# 3600

# %%
type(1)
# Out:
# int

# %% [markdown]
# ### relational operators

# %%
2==3
# Out:
# False

# %%
2!=3
# Out:
# True

# %%
2<10
# Out:
# True

# %%
10>20
# Out:
# False

# %% [markdown]
# ### logical operators

# %%
False and True
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# ### assignment operators

# %%
a=1
type(a)
# Out:
# int

# %%
a=b=c=10

# %%
a,b,c
# Out:
# 10

# %%
a,b,c=1,2,3

# %%
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b=b,a

# %%
a,b
# Out:
# (10, 10)

# %%
a="hello manisha"
type(a)
# Out:
# str

# %%
a+=1
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-4af3787215d0> in <module>
# ----> 1 a+=1
#       2 a
#
# TypeError: can only concatenate str (not "int") to str

# %%
a,b=1,2
a,b=b,a
a,b
# Out:
# (2, 1)

# %%
a+=1
a
# Out:
# 4

# %% [markdown]
# ### bit wise operators

# %%
4&7
# Out:
# 4

# %%
7|4
# Out:
# 7

# %%
8<<2
# Out:
# 32

# %%
8>>2
# Out:
# 2

# %% [markdown]
# ### identify operators

# %%
2 == 3
# Out:
# False

# %%
2 is 3
# Out:
# False

# %%
2!=3
# Out:
# True

# %%
2 is not 3
# Out:
# True

# %% [markdown]
# ### membership operators

# %%
"ap" in "apssdc"
# Out:
# True

# %%
"Ap" in "apssdc"
# Out:
# False

# %%
"t" not in "apssdc"
# Out:
# True
